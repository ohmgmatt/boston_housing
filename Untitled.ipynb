# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
headers = ['CRIM', 'ZN', 'NDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']

# %%
f = open("Dataset.data", "r")

counter = 1
tester = []

for line in f:
    if (counter % 2) == 0:
        second = line.rstrip('\t\n')
        tester.append(first+second)
    else:
        first = line.rstrip(' \\\n').lstrip()
    counter += 1

writer = pd.DataFrame({'items':tester})
writer.to_csv("dataset.csv", index=False)

# %%
df = pd.read_csv("dataset.csv", sep='\s+',skiprows = 1, header=None, names = headers)

# %%
df.describe()
# Out:
#              CRIM          ZN        NDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677082   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df['LSTAT'].plot.hist()

# %% [markdown]
# CRIM - right skewed, check out whats happening in the higher ranges, expecting higher amount to be poorer
# ZN - right skewed? expecting higher amount to be more wealthy
# NDSU - biodal, peaks at 7 & 17?, find relationship
# CHAS - see reltionship between CHAS and MEDV since its a small amount
# NOX - explore higher values and see prices
# RM - houses have a lot of rooms in boston
# AGE - left skewed with really high age mean
# DIS - right skewed, a lot seem to have employment centres nearby
# RAD - bimodal,
# TAX - bimodal
# PTRATIO - higher is worse, spike in 21 but a good spread
# B - check for wealth ratio
# LSTAT - lower pops for lower wealth?
# MEDV - normal from 0 to 40 but then spikes?

# %%
pd.plotting.scatter_matrix(df, figsize=(12,12), diagonal = 'kde')
plt.show()

# %% [markdown]
# A scatter matrix is cool but we're truly only interested in how the other variables affect MEDV. We can remove the rest and take a look there.

# %%
fig, axs = plt.subplots(3,4, figsize = (20, 12))
axs[0, 0].scatter(df['MEDV'], df['CRIM'])
axs[0, 0].set_title('CRIM')

axs[0, 1].scatter(df['MEDV'], df['ZN'])
axs[0, 1].set_title('ZN')

axs[0, 2].scatter(df['MEDV'], df['NDUS'])
axs[0, 2].set_title('NDUS')

axs[0, 3].scatter(df['MEDV'], df['NOX'])
axs[0, 3].set_title('NOX')

axs[1, 0].scatter(df['MEDV'], df['RM'])
axs[1, 0].set_title('RM')

axs[1, 1].scatter(df['MEDV'], df['AGE'])
axs[1, 1].set_title('AGE')

axs[1, 2].scatter(df['MEDV'], df['DIS'])
axs[1, 2].set_title('DIS')

axs[1, 3].scatter(df['MEDV'], df['RAD'])
axs[1, 3].set_title('RAD')

axs[2, 0].scatter(df['MEDV'], df['TAX'])
axs[2, 0].set_title('TAX')

axs[2, 1].scatter(df['MEDV'], df['PTRATIO'])
axs[2, 1].set_title('PTRATIO')

axs[2, 2].scatter(df['MEDV'], df['B'])
axs[2, 2].set_title('B')

axs[2, 3].scatter(df['MEDV'], df['LSTAT'])
axs[2, 3].set_title('LSTAT')
plt.show()

# %% [markdown]
# Alrighty that's a lot of same code so let's see if we can simplify it.

# %%
fig, axs = plt.subplots(3,4, figsize = (20, 12))
x_count = 0
y_count = 0

for x in headers:
    if x == 'CHAS':
        continue
    elif x == 'MEDV':
        continue
    
    
    if x_count < 3:
        pass
    else:
        break

    axs[x_count, y_count].scatter(df['MEDV'], df[x])
    axs[x_count, y_count].set_title(x)

    if y_count < 3:
        y_count += 1
        pass
    else:
        x_count += 1
        y_count = 0
plt.show()

# %% [markdown]
# A few interesting correlations we may want to take a look at would be CRIM, NDSU, RM, DIS, PTRATIO, and LSTAT

# %%
plt.scatter(df['MEDV'], df['CHAS'], alpha = 0.1)
plt.show()

# %%
df.plot.hexbin(x = 'MEDV', y = 'CHAS', gridsize = 10)

# %%
chas_1 = df[df['CHAS']==1]
chas_0 = df[df['CHAS']==0]

plt.hist(chas_1['MEDV'], label = '1', color = 'Red')
plt.hist(chas_0['MEDV'], alpha = 0.2, label = '0', color = 'Blue')
plt.legend(loc='upper right')
plt.title('MEDV by CHAS')
plt.show()

# %%
plt.hist(chas_1['MEDV'], label = '1', color = 'Red')
plt.title('MEDV (CHAS = 1)')
plt.show()

# %% [markdown]
# At first, I thought CHAS would be a good identifier but it looks like it seems insignificant. Looking at CHAS groups independently, it mimics the structure of how MEDV is split and seems to further the idea that the variable is insignificant.

# %%
df.head()
# Out:
#       CRIM    ZN  NDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0  2.31     0  0.538  6.575  65.2  4.0900    1  296.0     15.3
# 1  0.02731   0.0  7.07     0  0.469  6.421  78.9  4.9671    2  242.0     17.8
# 2  0.02729   0.0  7.07     0  0.469  7.185  61.1  4.9671    2  242.0     17.8
# 3  0.03237   0.0  2.18     0  0.458  6.998  45.8  6.0622    3  222.0     18.7
# 4  0.06905   0.0  2.18     0  0.458  7.147  54.2  6.0622    3  222.0     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
y = df['MEDV']
x = df.drop('MEDV', axis = 1)

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: MEDV, dtype: float64

# %%
x.head()
# Out:
#       CRIM    ZN  NDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO  \
# 0  0.00632  18.0  2.31     0  0.538  6.575  65.2  4.0900    1  296.0     15.3
# 1  0.02731   0.0  7.07     0  0.469  6.421  78.9  4.9671    2  242.0     17.8
# 2  0.02729   0.0  7.07     0  0.469  7.185  61.1  4.9671    2  242.0     17.8
# 3  0.03237   0.0  2.18     0  0.458  6.998  45.8  6.0622    3  222.0     18.7
# 4  0.06905   0.0  2.18     0  0.458  7.147  54.2  6.0622    3  222.0     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 5)

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (354, 13)
# (152, 13)
# (354,)
# (152,)

# %%
reg = LinearRegression()
reg.fit(x_train, y_train)

y_pred = reg.predict(x_test)

plt.scatter(y_test, y_pred)

plt.xlabel('Y_TRUE')
plt.ylabel('Y_PRED')

plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
# Out:
# Text(0.5, 1.0, 'Prices vs Predicted prices: $Y_i$ vs $\\hat{Y}_i$')

# %%
mse = mean_squared_error(y_test, y_pred)
print(mse)
# Out:
# 30.697037704088572

# %%
select = df[['CRIM', 'NDUS', 'RM', 'DIS', 'PTRATIO', 'LSTAT', 'MEDV']]

# %%
select.head()
# Out:
#       CRIM  NDUS     RM     DIS  PTRATIO  LSTAT  MEDV
# 0  0.00632  2.31  6.575  4.0900     15.3   4.98  24.0
# 1  0.02731  7.07  6.421  4.9671     17.8   9.14  21.6
# 2  0.02729  7.07  7.185  4.9671     17.8   4.03  34.7
# 3  0.03237  2.18  6.998  6.0622     18.7   2.94  33.4
# 4  0.06905  2.18  7.147  6.0622     18.7   5.33  36.2

# %%
x_select = select.drop('MEDV', axis = 1)
y_select = select['MEDV']

# %%
sx_train, sx_test, sy_train, sy_test = train_test_split(x_select, y_select, test_size = 0.3, random_state = 5)

# %%
reg = LinearRegression()
reg.fit(sx_train, sy_train)

sy_pred = reg.predict(sx_test)

plt.scatter(sy_test, sy_pred)

plt.xlabel('sY_TRUE')
plt.ylabel('sY_PRED')

plt.title("Prices vs Predicted prices: $Y_i$ vs $\hat{Y}_i$")
# Out:
# Text(0.5, 1.0, 'Prices vs Predicted prices: $Y_i$ vs $\\hat{Y}_i$')

# %%
mse = mean_squared_error(sy_test, sy_pred)
print(mse)
# Out:
# 34.36548450303691

# %% [markdown]
# It looks like our selected choices did worse in the mean squared error. this could be because we're limiting other while emphasizing the error in the fea
